# %%
import random
from running_coordinator import PauseResumeTrainingCoordinator

def main():
    """Main function to run the pause-resume training"""
    random.seed(42)

    # Create and run trainer
    trainer = PauseResumeTrainingCoordinator(num_work_centers=3, num_machines=[2,1,2])
    trainer.train()

if __name__ == "__main__":
    main()
# Out:
# Initialize the simulation environment with WorkCenter-level strategies
# FIS
# FIS
# FIS
# FIS
# FIS
# Starting Simulation with WorkCenter Strategy Management...
# Input Parameters:
#   Intervals : 2
#   Interval Duration: 0.016666666666666666 hours
#   Future Duration: 0.016666666666666666 hours
#   Strategies: ['SPT', 'EDD', 'FIFO', 'LPT', 'FIS']
#
# ============================================================
# Episode 1/2
# ============================================================
# Initialize the simulation environment with WorkCenter-level strategies
# FIS
# FIS
# FIS
# FIS
# FIS
#
# --- Interval 1/6 ---
# Running main simulation from 0 to 60
#
# --- Recently Completed Jobs (last 240 time units): 0 ---
# No recently completed jobs.
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_SPT
# SPT
# SPT
# FIS
# FIS
# FIS
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'FIS', 3: 'FIS'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_SPT
# FIS
# FIS
# SPT
# FIS
# FIS
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIS', 2: 'SPT', 3: 'FIS'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_SPT
# FIS
# FIS
# FIS
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIS', 2: 'FIS', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_EDD
# EDD
# EDD
# FIS
# FIS
# FIS
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'EDD', 2: 'FIS', 3: 'FIS'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_EDD
# FIS
# FIS
# EDD
# FIS
# FIS
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIS', 2: 'EDD', 3: 'FIS'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_EDD
# FIS
# FIS
# FIS
# EDD
# EDD
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIS', 2: 'FIS', 3: 'EDD'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_FIFO
# FIFO
# FIFO
# FIS
# FIS
# FIS
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIFO', 2: 'FIS', 3: 'FIS'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_FIFO
# FIS
# FIS
# FIFO
# FIS
# FIS
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIS', 2: 'FIFO', 3: 'FIS'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_FIFO
# FIS
# FIS
# FIS
# FIFO
# FIFO
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIS', 2: 'FIS', 3: 'FIFO'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_LPT
# LPT
# LPT
# FIS
# FIS
# FIS
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'LPT', 2: 'FIS', 3: 'FIS'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_LPT
# FIS
# FIS
# LPT
# FIS
# FIS
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIS', 2: 'LPT', 3: 'FIS'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_LPT
# FIS
# FIS
# FIS
# LPT
# LPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIS', 2: 'FIS', 3: 'LPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_FIS
# FIS
# FIS
# FIS
# FIS
# FIS
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIS', 2: 'FIS', 3: 'FIS'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_FIS
# FIS
# FIS
# FIS
# FIS
# FIS
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIS', 2: 'FIS', 3: 'FIS'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_FIS
# FIS
# FIS
# FIS
# FIS
# FIS
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIS', 2: 'FIS', 3: 'FIS'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# WorkCenter 1: Optimal Strategy = SPT, Reward = 0.00
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# WorkCenter 2: Optimal Strategy = SPT, Reward = 0.00
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# WorkCenter 3: Optimal Strategy = SPT, Reward = 0.00
# WorkCenter 1 strategy updated to: SPT
# WorkCenter 2 strategy updated to: SPT
# WorkCenter 3 strategy updated to: SPT
#
# Interval 1 Complete:
#   Current Time: 60
#   Optimal Strategies: {1: 'SPT', 2: 'SPT', 3: 'SPT'}
#   Total WC Experiences: 15
#   Optimal WC Experiences: 3
#
# --- Interval 2/6 ---
# Running main simulation from 60 to 120
#
# --- Recently Completed Jobs (last 240 time units): 0 ---
# No recently completed jobs.
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_SPT
# SPT
# SPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_SPT
# SPT
# SPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_SPT
# SPT
# SPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_EDD
# EDD
# EDD
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'EDD', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_EDD
# SPT
# SPT
# EDD
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'EDD', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_EDD
# SPT
# SPT
# SPT
# EDD
# EDD
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'EDD'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_FIFO
# FIFO
# FIFO
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIFO', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_FIFO
# SPT
# SPT
# FIFO
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'FIFO', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_FIFO
# SPT
# SPT
# SPT
# FIFO
# FIFO
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'FIFO'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_LPT
# LPT
# LPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'LPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_LPT
# SPT
# SPT
# LPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'LPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_LPT
# SPT
# SPT
# SPT
# LPT
# LPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'LPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_FIS
# FIS
# FIS
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIS', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_FIS
# SPT
# SPT
# FIS
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'FIS', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_FIS
# SPT
# SPT
# SPT
# FIS
# FIS
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'FIS'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# WorkCenter 1: Optimal Strategy = SPT, Reward = 0.00
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# WorkCenter 2: Optimal Strategy = SPT, Reward = 0.00
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# WorkCenter 3: Optimal Strategy = SPT, Reward = 0.00
# WorkCenter 1 strategy updated to: SPT
# WorkCenter 2 strategy updated to: SPT
# WorkCenter 3 strategy updated to: SPT
#
# Interval 2 Complete:
#   Current Time: 120
#   Optimal Strategies: {1: 'SPT', 2: 'SPT', 3: 'SPT'}
#   Total WC Experiences: 30
#   Optimal WC Experiences: 6
#
# --- Interval 3/6 ---
# Running main simulation from 120 to 180
#
# --- Recently Completed Jobs (last 240 time units): 0 ---
# No recently completed jobs.
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_SPT
# SPT
# SPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_SPT
# SPT
# SPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_SPT
# SPT
# SPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_EDD
# EDD
# EDD
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'EDD', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_EDD
# SPT
# SPT
# EDD
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'EDD', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_EDD
# SPT
# SPT
# SPT
# EDD
# EDD
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'EDD'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_FIFO
# FIFO
# FIFO
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIFO', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_FIFO
# SPT
# SPT
# FIFO
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'FIFO', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_FIFO
# SPT
# SPT
# SPT
# FIFO
# FIFO
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'FIFO'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_LPT
# LPT
# LPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'LPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_LPT
# SPT
# SPT
# LPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'LPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_LPT
# SPT
# SPT
# SPT
# LPT
# LPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'LPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_FIS
# FIS
# FIS
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIS', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_FIS
# SPT
# SPT
# FIS
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'FIS', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_FIS
# SPT
# SPT
# SPT
# FIS
# FIS
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'FIS'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# WorkCenter 1: Optimal Strategy = SPT, Reward = 0.00
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# WorkCenter 2: Optimal Strategy = SPT, Reward = 0.00
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# WorkCenter 3: Optimal Strategy = SPT, Reward = 0.00
# WorkCenter 1 strategy updated to: SPT
# WorkCenter 2 strategy updated to: SPT
# WorkCenter 3 strategy updated to: SPT
#
# Interval 3 Complete:
#   Current Time: 180
#   Optimal Strategies: {1: 'SPT', 2: 'SPT', 3: 'SPT'}
#   Total WC Experiences: 45
#   Optimal WC Experiences: 9
#
# --- Interval 4/6 ---
# Running main simulation from 180 to 240
# Machine Starting time is : 180
# Machine Starting time is : 180
# Machine Starting time is : 180
# Machine Starting time is : 180
# Machine Starting time is : 180
#
# --- Recently Completed Jobs (last 240 time units): 12 ---
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_SPT
# SPT
# SPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_SPT
# SPT
# SPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_SPT
# SPT
# SPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_EDD
# EDD
# EDD
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'EDD', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_EDD
# SPT
# SPT
# EDD
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'EDD', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_EDD
# SPT
# SPT
# SPT
# EDD
# EDD
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'EDD'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_FIFO
# FIFO
# FIFO
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIFO', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_FIFO
# SPT
# SPT
# FIFO
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'FIFO', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_FIFO
# SPT
# SPT
# SPT
# FIFO
# FIFO
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'FIFO'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_LPT
# LPT
# LPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'LPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_LPT
# SPT
# SPT
# LPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'LPT', 3: 'SPT'} strategies
# ...
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# WorkCenter 2: Optimal Strategy = SPT, Reward = 0.00
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# WorkCenter 3: Optimal Strategy = SPT, Reward = 0.00
# WorkCenter 1 strategy updated to: SPT
# WorkCenter 2 strategy updated to: SPT
# WorkCenter 3 strategy updated to: SPT
#
# Interval 5 Complete:
#   Current Time: 660
#   Optimal Strategies: {1: 'SPT', 2: 'SPT', 3: 'SPT'}
#   Total WC Experiences: 165
#   Optimal WC Experiences: 33
#
# --- Interval 6/6 ---
# Running main simulation from 660 to 720
# Machine 6 breakdown at 666.7963364040414
# Machine 6 repaired at 701.3156053243472
#
# --- Recently Completed Jobs (last 240 time units): 58 ---
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_SPT
# SPT
# SPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_SPT
# SPT
# SPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_SPT
# SPT
# SPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_EDD
# EDD
# EDD
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'EDD', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_EDD
# SPT
# SPT
# EDD
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'EDD', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_EDD
# SPT
# SPT
# SPT
# EDD
# EDD
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'EDD'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_FIFO
# FIFO
# FIFO
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIFO', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_FIFO
# SPT
# SPT
# FIFO
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'FIFO', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_FIFO
# SPT
# SPT
# SPT
# FIFO
# FIFO
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'FIFO'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_LPT
# LPT
# LPT
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'LPT', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_LPT
# SPT
# SPT
# LPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'LPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_LPT
# SPT
# SPT
# SPT
# LPT
# LPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'LPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC1_FIS
# FIS
# FIS
# SPT
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'FIS', 2: 'SPT', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC2_FIS
# SPT
# SPT
# FIS
# SPT
# SPT
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'FIS', 3: 'SPT'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
#   Evaluating strategy combination: WC3_FIS
# SPT
# SPT
# SPT
# FIS
# FIS
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# Running future-simulation to evaluate it over {1: 'SPT', 2: 'SPT', 3: 'FIS'} strategies
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# using privious jobs
# Sub-simulation complete. Metrics: {'total_tardiness': 0, 'mean_tardiness': 0, 'throughput': 0, 'utilization': 0.0, 'jobs_completed': 0, 'new_jobs_created': 0}
# Info: 1 machine states provided, less than max_machines=2. Filling remaining with empty states.
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 1
# reward Calulation for workcenter 1
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# WorkCenter 1: Optimal Strategy = SPT, Reward = 0.00
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 2
# reward Calulation for workcenter 2
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# WorkCenter 2: Optimal Strategy = SPT, Reward = 0.00
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# workcenter ID: 3
# reward Calulation for workcenter 3
# processed jobs count:  {1: {'over_5min': 0, 'under_5min': 0}, 2: {'over_5min': 0, 'under_5min': 0}, 5: {'over_5min': 0, 'under_5min': 0}, 6: {'over_5min': 0, 'under_5min': 0}}
# cost :- 0
# WorkCenter 3: Optimal Strategy = SPT, Reward = 0.00
# WorkCenter 1 strategy updated to: SPT
# WorkCenter 2 strategy updated to: SPT
# WorkCenter 3 strategy updated to: SPT
#
# Interval 6 Complete:
#   Current Time: 720
#   Optimal Strategies: {1: 'SPT', 2: 'SPT', 3: 'SPT'}
#   Total WC Experiences: 180
#   Optimal WC Experiences: 36
#
# Episode 2 Complete:
#   Simulation Time: 720
#   Jobs Completed: 129/237
#   Total WC Experiences: 180
#   Optimal WC Experiences: 36
#
# Training Complete!

# %%
# Out:
# sys.executable: C:\Users\91817\anaconda3\envs\fj_env\python.exe
# sys.version: 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]
# site-packages: C:\Users\91817\anaconda3\envs\fj_env\Lib\site-packages
# simpy importable? True
# simpy.version: 4.1.1
